# %% [markdown]
# <a href="https://colab.research.google.com/github/EvioSilva/Dio---Desafio-Github---Primeiro-Reposit-rio/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
df1 = pd.read_excel("ARACAJU.xlsx")
df2 = pd.read_excel("FORTALEZA.xlsx")
df3 = pd.read_excel("NATAL.xlsx")
df5 = pd.read_excel("SALVADOR.xlsx")

# %%
df["CIDADE"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-32060bf8811f> in <module>
# ----> 1 df["CIDADE"].value_counts()
#
# NameError: name 'df' is not defined

# %%
df5.head()
# Out:
#      CIDADE        DATA  VENDAS  LOJAID   QTD
# 0  SALVADOR  15/19/2022     142     1520    2

# %%
df2.head()
# Out:
#     CIDADE        DATA  VENDAS  LOJAID   QTD
# 0  ARACAJU  15/19/2022     142     1520    2

# %%
df = pd.concat([df1,df2,df3,df5])

# %%
df.head()
# Out:
#       CIDADE        DATA  VENDAS  LOJAID   QTD
# 0    ARACAJU  15/19/2022     142     1520    2
# 0  FORTALEZA  15/19/2022     142     1520    2
# 0      NATAL  15/19/2022     142     1520    2
# 0   SALVADOR  15/19/2022     142     1520    2

# %%
# Out:
#       CIDADE        DATA  VENDAS  LOJAID   QTD
# 0    ARACAJU  15/19/2022     142     1520    2
# 0  FORTALEZA  15/19/2022     142     1520    2
# 0      NATAL  15/19/2022     142     1520    2
# 0   SALVADOR  15/19/2022     142     1520    2

# %%
df.dtypes
# Out:
# CIDADE     object
# DATA       object
# VENDAS      int64
# LOJAID      int64
# QTD         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CIDADE     0
# DATA       0
# VENDAS     0
# LOJAID     0
# QTD        0
# dtype: int64

# %%
df["RECEITAS"] = df["VENDAS"].mul(df["QTD"])

# %%
df.head()
# Out:
#       CIDADE        DATA  VENDAS  LOJAID   QTD  Receitas  RECEITAS
# 0    ARACAJU  15/19/2022     142     1520    2       284       284
# 0  FORTALEZA  15/19/2022     142     1520    2       284       284
# 0      NATAL  15/19/2022     142     1520    2       284       284
# 0   SALVADOR  15/19/2022     142     1520    2       284       284

# %%
df["RECEITAS/VENDAS"] = df["RECEITAS"] / df["VENDAS"]

# %%
df.head()
# Out:
#       CIDADE        DATA  VENDAS  LOJAID   QTD  Receitas  RECEITAS  \
# 0    ARACAJU  15/19/2022     142     1520    2       284       284
# 0  FORTALEZA  15/19/2022     142     1520    2       284       284
# 0      NATAL  15/19/2022     142     1520    2       284       284
# 0   SALVADOR  15/19/2022     142     1520    2       284       284
#
#    RECEITAS/VENDAS
# 0              2.0
# 0              2.0
# 0              2.0
# 0              2.0

# %%
df["RECEITAS"].max()
# Out:
# 284

# %%
df["CIDADE"].value_counts()
# Out:
#   File "<ipython-input-9-60608e641f93>", line 1
#     df.["CIDADE"].value_counts()
#        ^
# SyntaxError: invalid syntax
